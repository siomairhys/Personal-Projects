# %% [markdown]
# # Pandas Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Locating the dataset to use and specified the index
df = pd.read_csv(r"C:\Users\ADMIN\OneDrive - siomairhys\Portfolio Project\Resources,Templates and Codes\Netflix Userbase Edited.csv")
df = df.set_index('Age')

df
# Out:
#      User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# Age
# 28         1             Basic               10  15-01-22          06-10-23
# 35         2           Premium               15  09-05-21          22-06-23
# 42         3          Standard               12  28-02-23          27-06-23
# 51         4          Standard               12  07-10-22          26-06-23
# 33         5             Basic               10  05-01-23          28-06-23
# 29         6           Premium               15  18-03-22          27-06-23
# 46         7          Standard               12  12-09-21          25-06-23
# 39         8             Basic               10  04-02-23          24-06-23
# 37         9          Standard               12  20-10-22          23-06-23
# 44        10           Premium               15  01-07-23          22-06-23
# 31        11             Basic               10  16-05-22          22-06-23
# ...

# %%
#Visualizing the Monthly Revenue of my dataset
df.plot(kind = 'bar', title = 'Monthly Revenue by Age', ylabel= 'Price')
# Out:
# <Axes: title={'center': 'Monthly Revenue by Age'}, xlabel='Age', ylabel='Price'>

# %%
#Separated the User ID and Monthly Revenue
df.plot(kind = 'bar', subplots = True)
# Out:
# array([<Axes: title={'center': 'User ID'}, xlabel='Age'>,
#        <Axes: title={'center': 'Monthly Revenue'}, xlabel='Age'>],
#       dtype=object)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Age  User ID Subscription Type  Monthly Revenue Join Date  \
# 0    28        1             Basic               10  15-01-22
# 1    35        2           Premium               15  09-05-21
# 2    42        3          Standard               12  28-02-23
# 3    51        4          Standard               12  07-10-22
# 4    33        5             Basic               10  05-01-23
# 5    29        6           Premium               15  18-03-22
# 6    46        7          Standard               12  12-09-21
# 7    39        8             Basic               10  04-02-23
# 8    37        9          Standard               12  20-10-22
# 9    44       10           Premium               15  01-07-23
# 10   31       11             Basic               10  16-05-22
# 11   45       12           Premium               15  23-03-23
# 12   48       13          Standard               12  30-11-21
# 13   27       14             Basic               10  08-01-22
# ...

# %%
df.set_index('Join Date', inplace= True)

df
# Out:
#            Age  User ID Subscription Type  Monthly Revenue Last Payment Date  \
# Join Date
# 15-01-22    28        1             Basic               10          06-10-23
# 09-05-21    35        2           Premium               15          22-06-23
# 28-02-23    42        3          Standard               12          27-06-23
# 07-10-22    51        4          Standard               12          26-06-23
# 05-01-23    33        5             Basic               10          28-06-23
# 18-03-22    29        6           Premium               15          27-06-23
# 12-09-21    46        7          Standard               12          25-06-23
# 04-02-23    39        8             Basic               10          24-06-23
# 20-10-22    37        9          Standard               12          23-06-23
# 01-07-23    44       10           Premium               15          22-06-23
# 16-05-22    31       11             Basic               10          22-06-23
# ...

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Join Date'>

# %%
df.plot.scatter(x = 'User ID', y = 'Age', s = 100)
# Out:
# <Axes: xlabel='User ID', ylabel='Age'>

# %%
df.plot.hist(bins = 30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize= (10,5))
# Out:
# <Axes: xlabel='Join Date'>

# %%
df.plot.pie(y = 'Age', figsize = (10,20))
# Out:
# <Axes: ylabel='Age'>
